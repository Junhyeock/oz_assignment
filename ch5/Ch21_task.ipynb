# %% [markdown]
# 안녕하세요. 수강생 여러분~! Chapter21 ~ 32 수업은 잘 들으셨나요?
#
# Chapter21 ~ 32의 수업 내용을 바탕으로 아래 문제를 풀어주시면 됩니다.
#
#
# <br>
#
#
# [**답변 입력 방법**]
#
# 문제 아래에 있는 코드 입력창에 정답코드를 작성하신 후  __▷ 버튼을 클릭해 코드를 실행__ 해보세요<br>

# %% [markdown]
# ---

# %% [markdown]
# [문제 1]
# 사용자로부터 이름과 나이를 입력 받아, "안녕하세요, [이름]님! 당신은 [나이]살입니다."라고 출력하는 함수 greet_user를 작성하세요.

# %%
name = input('이름 입력: ')
age = input('나이 입력: ')
print(f'안녕하세요, {name}님! 당신은 {age}살 입니다.')

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ---

# %% [markdown]
# [문제 2] 여러 숫자를 입력받아 그 합계를 반환하는 함수 sum_numbers를 작성하세요. 이 때, 가변 매개변수를 사용하세요.

# %%
def sum_number(*args):
  sum = 0 
  for i in args:
    sum += i

  return sum
print(sum_number())

# %% [markdown]
# ---

# %% [markdown]
# [문제 3] 사용자의 이름을 출력하는 함수 print_name을 작성하세요. 만약 이름이 주어지지 않았다면, 기본값으로 "익명"을 사용하세요.

# %%
def print_name(name= '익명'):
  print(f'사용자의 이름은: {name}')

print_name()
print_name()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ---

# %% [markdown]
# [문제 4] 사용자의 이름, 나이, 성별을 출력하는 함수 print_info를 작성하세요. 이 때, 모든 매개변수는 키워드 매개변수로만 받도록 하세요.

# %%
def print_info():
    name = input('이름 입력: ')
    age = input('나이 입력: ')
    gender = input('성별 입력: ')
    print(f'사용자의 이름은 {name},  사용자의 나이는 {age}살이고, 사용자의 성별은 {gender}이다')


print_info()

# %% [markdown]
# ---

# %% [markdown]
# [문제 5] 두 개의 정수를 받아 합을 반환하는 함수 add를 작성하세요. 매개변수와 반환값에 타입 어노테이션을 추가하세요.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ---

# %% [markdown]
# [문제 6] 0부터 시작하여 n까지의 숫자 중에서 홀수만 생성하는 제너레이터 odd_numbers를 작성하세요.

# %%
def odd_numbers(n):
  for i in range(n + 1):
    if i % 2 == 1:
      yield i

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ---

# %% [markdown]
# [문제 7] 두 숫자를 더하는 람다 함수를 작성하고, 이를 변수에 할당한 후 사용하세요.

# %%
y = 5
pluse = lambda x: x + y
print(pluse(2))

y = 123
print(pluse(3))

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ---

# %% [markdown]
# [문제 8] 사용자로부터 3개의 숫자를 입력받아, 이를 튜플로 만든 후 최소값과 최대값을 출력하는 함수 min_max를 작성하세요.

# %%
numbers = (1, 30, 4)

print("최소값은", (min(numbers)), "최대값은", (max(numbers)))
# Out:
# 최소값은 1 최대값은 30

# %% [markdown]
# ---

# %% [markdown]
# [문제 9] 주어진 숫자가 짝수인지 확인하는 함수 is_even을 작성하세요. 짝수라면 True를, 아니라면 False를 반환하세요. 함수 내에서 조기 리턴을 활용하세요.

# %%
def is_even(n=6):
    if n % 2 == 0: 
        return True
    return False
print(is_even())
# Out:
# True

# %% [markdown]
# ---

# %% [markdown]
# [문제 10] 팩토리얼을 계산하는 재귀 함수 factorial을 작성하세요.

# %%
def factorial(n):
  if n == 1:
    return 1
  return n * factorial(n-1)

print(factorial(6))
# Out:
# 720

# %% [markdown]
# ---

# %% [markdown]
# [문제 11] 문자열 리스트를 받아, 각 문자열의 길이를 출력하는 함수 print_lengths를 작성하세요.

# %%
words = ["python", "java", "linux"]

def print_lengths(word_list):
  for word in word_list:
    print(len(word))

print_lengths(words)
# Out:
# 6
# 4
# 5

# %% [markdown]
# ---

# %% [markdown]
# [문제 12] 두 문자열을 받아서 긴 문자열을 반환하는 함수 longer_string을 작성하세요. 만약 두 문자열의 길이가 같다면, 첫 번째 문자열을 반환하세요.

# %%
words = ["hello", "bread"]

def longer_string(word_list):
    if len(word_list[0]) == len(word_list[1]):
      return word_list[0]

    else:
      return word_list[1]
    
print(longer_string(words))
# Out:
# hello
